# %% [markdown]
# # Load the required packages

# %%
import os
import scanpy as sc
import pandas as pd
import numpy as np
import RedeFISH
import time
import sys

# %% [markdown]
# # Load the required datasets

# %%
device = "cuda"

# The transcripts file must contain the x, y, and gene columns of the transcripts.
data = pd.read_csv("example_data/st_data.HumanBreastCancer.csv")
# The Scanpy h5ad file of gene expression must contain .obs['annotation'] corresponding to the annotation of each cell.
sc_data = sc.read("example_data/sc_data.HumanBreastCancer.h5ad")
sc_data.var_names_make_unique()

coordinate = np.asarray([data['x'], data['y']]).T

# %% [markdown]
# # Estimate prior cell location

# %%
# scale refer to prior cell radius, typically set to approximately 6.5 µm, which corresponds to about 30 pixels in this dataset.
scale = 6.5

model = RedeFISH.center_selection(scale, data, sc_data)
estimated_cell_locations = model.predict_cell_location()
# Out:
# Initializing ...
# Choosing Gene ...
# Grouping Gene ...
# Begin cell location prediction ...
# Finish cluster 0: 17078 9066659 40.59599356236682
# 	Related gene: ANKRD30A|CEACAM6|ERBB2|FASN|FOXA1|KRT7|MLPH|SCD|TACSTD2
# Finish cluster 1: 31855 3164924 14.931716184741237
# 	Related gene: LUM|MMP2|PDGFRA|PDGFRB|POSTN
# Finish cluster 2: 22486 1056064 5.973780944385196
# 	Related gene: APOC1|C1QA|CD163|CD68|ITGAX|LYZ|PDK4
# Finish cluster 3: 17801 563661 5.550839432618517
# 	Related gene: CCL5|CD3E|IL7R|TRAC
# Finish cluster 4: 14172 285403 3.6877071251035627
# 	Related gene: AQP1|EGFL7|VWF
# Finish cluster 5: 23161 262922 3.60205848403232
# 	Related gene: CENPF|MKI67|TOP2A
# Finish cluster 6: 24304 257106 2.657965805928911
# 	Related gene: DERL3|ITM2C|MZB1
# Finish cluster 7: 9934 223280 4.441352799410441
# 	Related gene: KRT14|KRT15|KRT5
# Finish cluster 8: 7177 54174 2.118207742489941
# 	Related gene: CD1C|CPA3|MMP12
# Finish cluster 9: 5494 53474 2.8074429392230247
# ...

# %% [markdown]
# # Running RedeFISH using estimated prior cell location

# %%
if __name__ == "__main__":

    # If the input prior is the cell location, set boundary_prior = False.
    model = RedeFISH.alignment(coordinate,
                               list(data['gene']),
                               estimated_cell_locations,
                               sc_data,
                               scale = scale,
                               boundary_prior = False,
                               worker_number = 16,
                               output_dir = "test_segmentation",
                               device=device).to(device)

    model.train()
# Out:
# Running RedeFISH ...
#
# Initialing data ...
#
# Cell type distribution of sc/snRNA:
# annotation
# 1     2653
# 2     2245
# 3     2124
# 4     1988
# 5     1724
# 6     1690
# 7     1672
# 8     1518
# 9     1469
# 10    1391
# 11    1359
# 13    1264
# 15    1218
# 12    1188
# 16    1097
# 14    1088
# 17     943
# 18     886
# 19     746
# 20     554
# 21     500
# 22     237
# Name: count, dtype: int64
# Intersection Gene: 307
#
# Auto select batch size: 873291
#
#   Begin training ...
#   Epoch: 1/500 	Segmentation Loss: 0.24323225 	Deconvolution Loss: 1.4532552
#   Epoch: 2/500 	Segmentation Loss: 0.22100382 	Deconvolution Loss: 1.4319799
#   Epoch: 3/500 	Segmentation Loss: 0.101399265 	Deconvolution Loss: 1.54277
#   Epoch: 4/500 	Segmentation Loss: 0.07752726 	Deconvolution Loss: 1.5354544
#   Epoch: 5/500 	Segmentation Loss: 0.0755625 	Deconvolution Loss: 1.4893725
#   Epoch: 6/500 	Segmentation Loss: 0.07185535 	Deconvolution Loss: 1.4319458
# ...
